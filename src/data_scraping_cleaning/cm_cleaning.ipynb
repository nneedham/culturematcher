# %% [markdown]
# <h1>Culture Match Data Cleaning</h1>
# Now that we have scraped our required information from Glassdoor, let's clean it up so that it will be useful in our matching model.

# %%
#import required libraries
import pandas as pd

#import datasets
df_jobs = pd.read_csv("scraped_df.csv")
df_companies = pd.read_csv("fortune_500.csv")

# %% [markdown]
# Let's look at the columns to see what we have imported for both databases.

# %%
df_jobs.head()
# Out:
#                                      Job Title  Salary Estimate  \
# 0  CDL-A Truck Driver - Walmart Transportation               -1
# 1                        Automotive Technician               -1
# 2       Truck Driver - Night Runs (Home Daily)               -1
# 3                             Warehouse Worker               -1
# 4                              Freight Handler               -1
#
#                                      Job Description  Rating  Company Name  \
# 0  LOCATION HURRICANE, UT\nCAREER AREA Drivers & ...     3.3  Walmart\n3.3
# 1  Automotive Technician\n\nYoull discover more t...     3.3  Walmart\n3.3
# 2  LOCATION POTTSVILLE, PA\nCAREER AREA Drivers &...     3.3  Walmart\n3.3
# 3  As a Freight Handler at Walmart Supply Chain, ...     3.3  Walmart\n3.3
# 4  As a Freight Handler at Walmart Supply Chain, ...     3.3  Walmart\n3.3
#
#            Location     Headquarters                    Size  Founded  \
# 0    Washington, UT  Bentonville, AR  1001 to 5000 employees     1962
# 1    Albert Lea, MN  Bentonville, AR  1001 to 5000 employees     1962
# 2    Shenandoah, PA  Bentonville, AR  1001 to 5000 employees     1962
# 3  Pauls Valley, OK  Bentonville, AR  1001 to 5000 employees     1962
# 4  Pauls Valley, OK  Bentonville, AR  1001 to 5000 employees     1962
#
#   Type of ownership  ...             Revenue  \
# 0  Company - Public  ...  $10+ billion (USD)
# 1  Company - Public  ...  $10+ billion (USD)
# 2  Company - Public  ...  $10+ billion (USD)
# 3  Company - Public  ...  $10+ billion (USD)
# 4  Company - Public  ...  $10+ billion (USD)
#
#                         Competitors Word count civic  family  industrial  \
# 0  Target, Costco Wholesale, Amazon        612     2       6           5
# 1  Target, Costco Wholesale, Amazon        195     1       2           2
# 2  Target, Costco Wholesale, Amazon        627     2       6           5
# 3  Target, Costco Wholesale, Amazon        262     5       0           4
# 4  Target, Costco Wholesale, Amazon        262     5       0           4
#
#    inspired  market  popular  sustainable
# 0         8      10        5            9
# 1         6       6        1            5
# 2         8      10        5            9
# 3         6       5        0           11
# 4         6       5        0           11
#
# [5 rows x 22 columns]

# %%
df_companies.head()
# Out:
#    Rank                Title                            Website  Employees  \
# 0    94                   3M                  http://www.3m.com      91584
# 1   135  Abbott Laboratories              http://www.abbott.com      75000
# 2   111               AbbVie              http://www.abbvie.com      30000
# 3   500       ABM Industries                 http://www.abm.com     110000
# 4   406  Activision Blizzard  http://www.activisionblizzard.com       9500
#
#               Sector                          Industry         Hqlocation  \
# 0        Industrials                     Miscellaneous       St. Paul, MN
# 1        Health Care    Medical Products and Equipment    Abbott Park, IL
# 2        Health Care                   Pharmaceuticals  North Chicago, IL
# 3  Business Services  Diversified Outsourcing Services       New York, NY
# 4         Technology                 Computer Software   Santa Monica, CA
#
#                   Hqaddr         Hqcity Hqstate  ...  Revenues Revchange  \
# 0              3M Center       St. Paul      MN  ...     30109      -0.5
# 1    100 Abbott Park Rd.    Abbott Park      IL  ...     20853       0.9
# 2      1 N. Waukegan Rd.  North Chicago      IL  ...     25638      12.2
# 3        1 Liberty Plaza       New York      NY  ...      5145      -2.8
# 4  3100 Ocean Park Blvd.   Santa Monica      CA  ...      6608      41.7
#
#   Profits Prftchange Assets Totshequity hiring  hiring_freeze  layoffs  \
# 0  5050.0        4.5  32906     10298.0    1.0            1.0      0.0
# 1  1400.0      -68.3  52666     20538.0    1.0            1.0      0.0
# 2  5953.0       15.7  66099      4636.0    1.0            1.0      0.0
# 3    57.2        -25   2281       974.0    1.0            NaN      NaN
# 4   966.0        8.3  17452      9119.0    1.0            NaN      NaN
#
#    Offers rescinded
# 0               0.0
# 1               0.0
# 2               0.0
# 3               NaN
# 4               NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# Let's remove the columns that we won't need

# %%
df_jobs = df_jobs.drop(columns = ['Job Title','Job Description','Salary Estimate','Rating',
                   'Headquarters','Industry','Sector','Size','Location','Founded',
                   'Type of ownership','Revenue','Competitors'])

# %%
df_companies = df_companies.drop(columns = ['Rank', 'Website', 'Hqlocation', 'Hqaddr', 'Hqcity', 
                           'Hqzip', 'Hqtel', 'Ceo','Ceo-title', 'Address', 'Ticker', 
                           'Fullname', 'Revenues', 'Revchange','Profits', 'Prftchange', 
                           'Assets', 'Totshequity', 'hiring','hiring_freeze', 
                           'layoffs', 'Offers rescinded'])

# %% [markdown]
# Let's collapse the df of the job descriptions

# %% [markdown]
# Now we should try to join the two tables.
# We will do this with the name.
# While it looks like the Company name is clean in df_companies, we will use that as the base to match with. Since Company name in df_jobs is full of regex and numbers and letters, we will split apart the name and then match the first word to the name in df_companies.

# %%
#set title of company data base to first word and lowercase
df_companies['updated_title'] = df_companies.apply(lambda x : x['Title'].rsplit()[0].lower(),axis=1)
df_companies = df_companies.drop(columns =['Title'])

#set title of job data base to lowercase and remove extra characters
df_jobs['company_name'] = df_jobs.apply(lambda x:x['Company Name'].rsplit("\n")[0].lower(),axis=1)
df_jobs = df_jobs.drop(columns = ['Company Name'])

for i in range(0,len(df_jobs)):
    for u in range(0,len(df_companies)):
        if df_jobs['company_name'][i] == df_companies['updated_title'][u]:
            df_jobs.loc[i,'employees'] = df_companies['Employees'][u]
            df_jobs.loc[i,'sector'] = df_companies['Sector'][u]
            df_jobs.loc[i,'industry'] = df_companies['Industry'][u]
            df_jobs.loc[i,'location'] = df_companies['Hqstate'][u]

# %% [markdown]
# Now we can drop the non matches. The rows that weren't matched will have a na we can just drop those rows.

# %%
df_jobs=df_jobs.dropna()

# %%
df_jobs
# Out:
#       Word count  civic  family  industrial  inspired  market  popular  \
# 0            612      2       6           5         8      10        5
# 1            195      1       2           2         6       6        1
# 2            627      2       6           5         8      10        5
# 3            262      5       0           4         6       5        0
# 4            262      5       0           4         6       5        0
# ...          ...    ...     ...         ...       ...     ...      ...
# 5864         389      6       4          19         3      11        0
# 5865         103      3       0           2         0       1        0
# 5870          79      2       0           2         0       2        0
# 5871         223      5       3           8         1       2        0
# 5872         133      1       1           3         1       1        0
#
#       sustainable company_name  employees             sector  \
# 0               9      walmart  2300000.0          Retailing
# 1               5      walmart  2300000.0          Retailing
# 2               9      walmart  2300000.0          Retailing
# 3              11      walmart  2300000.0          Retailing
# 4              11      walmart  2300000.0          Retailing
# ...           ...          ...        ...                ...
# 5864            6          abm   110000.0  Business Services
# 5865            8          abm   110000.0  Business Services
# 5870            4          abm   110000.0  Business Services
# 5871            5          abm   110000.0  Business Services
# 5872            6          abm   110000.0  Business Services
#
#                               industry location
# 0                General Merchandisers       AR
# 1                General Merchandisers       AR
# 2                General Merchandisers       AR
# 3                General Merchandisers       AR
# 4                General Merchandisers       AR
# ...                                ...      ...
# 5864  Diversified Outsourcing Services       NY
# 5865  Diversified Outsourcing Services       NY
# 5870  Diversified Outsourcing Services       NY
# 5871  Diversified Outsourcing Services       NY
# 5872  Diversified Outsourcing Services       NY
#
# [1380 rows x 13 columns]

# %% [markdown]
# At this point we have cleaned the data well enough to be used in the rest of our data pipeline.

# %%
df_jobs.to_csv(r'cc_cleaned_2.csv', index = False)
